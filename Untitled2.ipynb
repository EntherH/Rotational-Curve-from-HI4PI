# %%
# %matplotlib inline
import os
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
import healpy as hp
import astropy.units as u
from IPython.core.display import display,HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
from tqdm.notebook import tqdm
# Out:
# <style>.container { width:100% !important; }</style>

# %%
file = "NHI_HPX.fits"
file_obj = fits.open(file)

# %%
file_obj.info()
# Out:
# Filename: NHI_HPX.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       7   (1,)   int64
#   1  HI4PI-HPX     1 BinTableHDU     45   12582912R x 6C   [1K, 1D, 1D, 1D, 1D, 1D]

# %%
file_obj[0].header
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                   64 / array data type
# NAXIS   =                    1 / number of array dimensions
# NAXIS1  =                    1
# EXTEND  =                    T
# CHECKSUM= '8PQqAMOo1MOo8MOo'   / HDU checksum updated 2016-09-14T16:01:49
# DATASUM = '0       '           / data unit checksum updated 2016-09-14T16:01:49

# %%
HDU = file_obj[1]
HDU.columns
# Out:
# ColDefs(
#     name = 'HPXINDEX'; format = '1K'
#     name = 'RA2000'; format = '1D'; unit = 'deg'
#     name = 'DEC2000'; format = '1D'; unit = 'deg'
#     name = 'GLON'; format = '1D'; unit = 'deg'
#     name = 'GLAT'; format = '1D'; unit = 'deg'
#     name = 'NHI'; format = '1D'; unit = 'cm^(-2)'
# )

# %%
HDU.data['NHI']
# Out:
# array([9.17428016e+19, 9.24418447e+19, 9.39421415e+19, ...,
#        1.46523479e+20, 1.48363050e+20, 1.46759390e+20])

# %%
mp = hp.read_map(file,field = 'NHI')

# %%
hp.mollview(mp)
