# %%
import os
import numpy as np

# %%
np.sort(os.listdir('/data/cassegrain/HI4Pi/HEALPix/'))
# Out:
# array(['HPX_001.fits', 'HPX_002.fits', 'HPX_003.fits', 'HPX_004.fits',
#        'HPX_005.fits', 'HPX_006.fits', 'HPX_007.fits', 'HPX_008.fits',
#        'HPX_009.fits', 'HPX_010.fits', 'HPX_011.fits', 'HPX_012.fits',
#        'HPX_013.fits', 'HPX_014.fits', 'HPX_015.fits', 'HPX_016.fits',
#        'HPX_017.fits', 'HPX_018.fits', 'HPX_019.fits', 'HPX_020.fits',
#        'HPX_021.fits', 'HPX_022.fits', 'HPX_023.fits', 'HPX_024.fits',
#        'HPX_025.fits', 'HPX_026.fits', 'HPX_027.fits', 'HPX_028.fits',
#        'HPX_029.fits', 'HPX_030.fits', 'HPX_031.fits', 'HPX_032.fits',
#        'HPX_033.fits', 'HPX_034.fits', 'HPX_035.fits', 'HPX_036.fits',
#        'HPX_037.fits', 'HPX_038.fits', 'HPX_039.fits', 'HPX_040.fits',
#        'HPX_041.fits', 'HPX_042.fits', 'HPX_043.fits', 'HPX_044.fits',
#        'HPX_045.fits', 'HPX_046.fits', 'HPX_047.fits', 'HPX_048.fits',
#        'HPX_049.fits', 'HPX_050.fits', 'HPX_051.fits', 'HPX_052.fits',
# ...

# %%
os.listdir('/data/cassegrain/HI4Pi/HEALPix/')
# Out:
# ['HPX_065.fits',
#  'HPX_101.fits',
#  'HPX_192.fits',
#  'HPX_130.fits',
#  'HPX_054.fits',
#  'HPX_094.fits',
#  'HPX_119.fits',
#  'HPX_152.fits',
#  'HPX_036.fits',
#  'HPX_007.fits',
#  'HPX_163.fits',
#  'HPX_128.fits',
#  'HPX_134.fits',
#  'HPX_050.fits',
#  'HPX_061.fits',
#  'HPX_105.fits',
#  'HPX_088.fits',
#  'HPX_048.fits',
#  'HPX_003.fits',
#  'HPX_167.fits',
#  'HPX_090.fits',
#  'HPX_156.fits',
#  'HPX_032.fits',
#  'HPX_079.fits',
#  'HPX_075.fits',
#  'HPX_111.fits',
#  'HPX_120.fits',
#  'HPX_044.fits',
#  'HPX_182.fits',
#  'HPX_142.fits',
#  'HPX_026.fits',
#  'HPX_109.fits',
#  'HPX_084.fits',
#  'HPX_138.fits',
#  'HPX_017.fits',
#  'HPX_173.fits',
#  'HPX_124.fits',
#  'HPX_040.fits',
#  'HPX_186.fits',
#  'HPX_098.fits',
#  'HPX_071.fits',
#  'HPX_115.fits',
#  'HPX_013.fits',
#  'HPX_177.fits',
#  'HPX_058.fits',
#  'HPX_069.fits',
#  'HPX_146.fits',
#  'HPX_022.fits',
#  'HPX_080.fits',
#  'HPX_074.fits',
#  'HPX_110.fits',
#  'HPX_121.fits',
# ...
